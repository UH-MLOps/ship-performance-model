# %%
import pandas as pd

# %%
name = 'sensors_data_container_198886'

# %%
data = pd.read_excel(f'{name}.xlsx')
data
# Out:
#                 timestamps      draft  speedOverGround  courseOverGround  \
# 0      2021-06-28 17:10:00  11.685829              0.1        115.965892
# 1      2021-06-28 17:15:00  11.681920              0.0        308.704722
# 2      2021-06-28 17:20:00  11.677839              0.0        299.000000
# 3      2021-06-28 17:25:00  11.672375              0.0        165.635920
# 4      2021-06-28 17:30:00  11.665936              0.0        107.791000
# ...                    ...        ...              ...               ...
# 175789 2023-10-28 22:35:00  11.245183              9.5         79.964000
# 175790 2023-10-28 22:40:00  11.245764              9.5         80.087708
# 175791 2023-10-28 22:45:00  11.246249              9.5         80.203667
# 175792 2023-10-28 22:50:00  11.245373              9.5         80.185667
# 175793 2023-10-28 22:55:00  11.241804              9.5         80.062207
#
#         fuelMassFlow  windSpeed  windDirection  windWavesSignificantHeight  \
# ...

# %%
print(len(data.columns))

data.columns
# Out:
# 16
# Index(['timestamps', 'draft', 'speedOverGround', 'courseOverGround',
#        'fuelMassFlow', 'windSpeed', 'windDirection',
#        'windWavesSignificantHeight', 'windWavesZeroCrossingPeriod',
#        'windWavesDirection', 'swellSignificantHeight',
#        'swellZeroCrossingPeriod', 'swellDirection', 'currentSpeed',
#        'currentDirection', 'waterDepth'],
#       dtype='object')

# %%
data.describe()
# Out:
#                           timestamps          draft  speedOverGround  \
# count                         175794  175794.000000    175794.000000
# mean   2022-11-11 15:09:27.406737152      13.428913         5.813739
# min              2021-06-28 17:10:00       8.408648         0.000000
# 25%              2022-06-06 12:06:15      12.058171         0.600000
# 50%              2022-11-15 23:52:30      13.351721         6.700000
# 75%              2023-05-06 16:18:45      15.233927         9.100000
# max              2023-10-28 22:55:00      16.271344        12.600000
# std                              NaN       1.823600         3.806816
#
#        courseOverGround   fuelMassFlow      windSpeed  windDirection  \
# count     175794.000000  175794.000000  175794.000000  175794.000000
# mean         178.911702       0.775903       6.167732     188.841673
# min            0.000000       0.000000       0.014474       0.000159
# ...

# %%
data.to_csv(f'{name}.csv', index=False)
